# %%
import numpy as np
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('MSFT.csv')

# Calculate the daily log returns of the stock
df['LogReturns'] = np.log(df['Adj Close'] / df['Adj Close'].shift(1))

# Calculate the daily volatility (standard deviation of log returns)
sigma_daily = df['LogReturns'].std()

# Annualize the daily volatility (assuming 252 trading days in a year)
sigma_annual = sigma_daily * np.sqrt(252)

# Parameters
r = 0.05  # Example risk-free rate
T = 1  # Time to maturity (in years)
nrun = 100  # Number of periods
dt = T / nrun  # Time step
mu = r + 0.5 * sigma_annual ** 2  # Drift term
# Calculate up and down factors
u = np.exp(mu * dt + sigma_annual * np.sqrt(dt))  # Up factor
d = np.exp(mu * dt - sigma_annual * np.sqrt(dt))  # Down factor


# Calculate the risk-neutral probability
p = (np.exp(r * dt) - d) / (u - d)

# Calculate the future stock prices after an up move and a down move
f_u = u * df['Adj Close'].iloc[-1]
f_d = d * df['Adj Close'].iloc[-1]

# Calculate the present value of the expected future stock price
f = np.exp(-r * T) * (p * f_u + (1 - p) * f_d)

# Set the initial stock price to the last adjusted closing price in the DataFrame
S0 = df['Adj Close'].iloc[-1]

# Example strike price
K = 450
d
# Out:
# 0.9710077687830543

# %% [markdown]
# # Building the Stock Price Tree

# %%
# Calculate up and down factors
u = np.exp(mu * dt + sigma_annual * np.sqrt(dt))  # Up factor
d = np.exp(mu * dt - sigma_annual * np.sqrt(dt))  # Down factor

# Function to build the stock price tree
def build_stock_price_tree(S0, nrun, u, d):
    stock_prices = np.zeros((nrun + 1, nrun + 1))
    stock_prices[0, 0] = S0
    for j in range(1, nrun + 1):
        for i in range(j + 1):
            if i == 0:
                stock_prices[i, j] = stock_prices[i, j - 1] * u
            else:
                stock_prices[i, j] = stock_prices[i - 1, j - 1] * d
    return stock_prices

# %% [markdown]
# # Computing Option Prices

# %%
# Function to compute the put option price based on a given S0
def compute_option_price(stock_prices, K, nrun, p, r, dt):
    # Initialize option price tree
    option_values = np.zeros((nrun + 1, nrun + 1))
    
    # Compute final option values at maturity
    for i in range(nrun + 1):
        option_values[i, nrun] = max(0, K - stock_prices[i, nrun])  # Payoff for put option

    # Step back through the tree
    for j in range(nrun - 1, -1, -1):
        for i in range(j + 1):
            # Calculate the discounted theoretical value
            discounted_value = np.exp(-r * dt) * (p * option_values[i, j + 1] + (1 - p) * option_values[i + 1, j + 1])
            payoff = max(0, K - stock_prices[i, j])
            option_values[i, j] = max(payoff, discounted_value) 

    return option_values

# %% [markdown]
# # Adjusting S0 Until Convergence

# %%
# Set initial values
initial_S0 = S0
adjustment_factor = 0.01  # Delta
epsilon = 0.01  # Convergence threshold
iteration = 0
direction = -1  # Start by decreasing S0

while True:
    iteration += 1

    # Build the stock price tree based on the current S0
    stock_prices = build_stock_price_tree(S0, nrun, u, d)

    # Compute the option prices based on the updated stock price tree
    option_values = compute_option_price(stock_prices, K, nrun, p, r, dt)

    # Calculate the discounted option value at the root node (0,0)
    f_0 = np.exp(-r * dt) * (p * option_values[0, 1] + (1 - p) * option_values[1, 1])
    max_payoff_0 = max(0, K - S0)

    # Check the convergence condition
    if abs(f_0 - max_payoff_0) < epsilon:
        break
    else:
        # Adjust S0 based on direction
        S0 += direction * adjustment_factor

        if S0 <= 0:
            # Reset to initial value and change direction to increasing S0
            S0 = initial_S0
            direction = 1  # Change direction to increasing S0

        if S0 >= K:
            # Stop the iteration if S0 exceeds the strike price K
            break

print("Final Adjusted S0:", S0)
print("Option Prices Tree:\n", option_values)
print("Stock Prices Tree:\n", stock_prices)
# Out:
# Final Adjusted S0: 313.7299880000801
# Option Prices Tree:
#  [[136.2796713  126.76490512 117.42905762 ...   0.           0.
#     0.        ]
#  [  0.         145.36574435 135.6733719  ...   0.           0.
#     0.        ]
#  [  0.           0.         154.19777113 ...   0.           0.
#     0.        ]
#  ...
#  [  0.           0.           0.         ... 432.44579832 431.88686745
#   431.31014005]
#  [  0.           0.           0.         ...   0.         432.95473379
#   432.41200757]
#  [  0.           0.           0.         ...   0.           0.
#   433.44891409]]
# Stock Prices Tree:
#  [[ 313.729988    323.7192418   334.02655634 ... 6769.85293948
#   6985.40702031 7207.82440558]
#  [   0.          304.63425565  314.33389869 ... 6370.7337865
#   6573.57979775 6782.88448483]
#  [   0.            0.          295.80222887 ... 5995.14484898
#   6186.03199954 6382.99705233]
#  ...
#  [   0.            0.            0.         ...   17.55420168
#     18.11313255   18.68985995]
#  [   0.            0.            0.         ...    0.
#     17.04526621   17.58799243]
#  [   0.            0.            0.         ...    0.
#      0.           16.55108591]]

# %% [markdown]
# # Final Tree Plotting (First 6 columns only)

# %%
import matplotlib.pyplot as plt
import networkx as nx

columns_to_plot = 6
# Function to plot the stock price and option price tree with ellipses and colored nodes
def plot_price_tree_partial(stock_prices, option_values, S0, K, nrun, columns_to_plot):
    G = nx.DiGraph()
    pos = {}
    labels = {}
    node_colors = []

    for j in range(columns_to_plot):
        for i in range(j + 1):
            intrinsic_value = max(K - stock_prices[i, j], 0)
            if option_values[i, j] == intrinsic_value:
                color = 'red'
            else:
                color = 'green'
            
            node_colors.append(color)
            labels[(i, j)] = f'S: {stock_prices[i, j]:.2f}\nO: {option_values[i, j]:.2f}'
            pos[(i, j)] = (j, -i)
            G.add_node((i, j))
            if j > 0:
                if i < j:
                    G.add_edge((i, j - 1), (i, j))
                if i > 0:
                    G.add_edge((i - 1, j - 1), (i, j))

    # Add ellipses to indicate that the tree continues
    for i in range(columns_to_plot + 1):
        labels[(i, columns_to_plot)] = '...'
        pos[(i, columns_to_plot)] = (columns_to_plot, -i)
        G.add_node((i, columns_to_plot))
        node_colors.append('lightblue')
        if i > 0:
            G.add_edge((i - 1, columns_to_plot - 1), (i, columns_to_plot))

    # Plot the graph
    plt.figure(figsize=(10, 8))
    nx.draw(G, pos, labels=labels, with_labels=True, node_size=3000, node_color=node_colors, font_size=8, font_weight='bold')
    plt.title(f"Stock and Option Price Binomial Tree (S0 = {S0:.2f})")
    plt.show()

# Plot the final adjusted tree
plot_price_tree_partial(stock_prices, option_values, S0, K, nrun, columns_to_plot)

# %% [markdown]
# # Free Boundary Path

# %%
# Initialize a list to store the results for each time step
results = []

# Iterate through the nodes of the tree at each time step
for j in range(1, nrun):  # Iterate through each time step, excluding the first and last time steps
    for i in range(j):  # Iterate through nodes at the current time step, up to j-1 (to compare i and i+1)
        # Calculate the payoff at the i-th and (i+1)-th nodes
        payoff_i = max(0, K - stock_prices[i, j])
        payoff_next = max(0, K - stock_prices[i + 1, j])

        # Check if the conditions are met
        if option_values[i, j] > payoff_i and option_values[i + 1, j] <= payoff_next:
            stock_price_i = stock_prices[i, j]
            stock_price_next = stock_prices[i + 1, j]
            results.append((j, i, stock_price_i, stock_price_next))  # Store the result
            break  # Move to the next time step once a match is found in the current column

# Output the results for each column
if results:
    for j, i, stock_price_i, stock_price_next in results:
        print(f"Time step {j}:")
        print(f"  Stock price at i-th node where option_values > max(K - S_t^(i)): {stock_price_i:.2f}")
        print(f"  Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): {stock_price_next:.2f}")
else:
    print("No such nodes found in the tree.")
# Out:
# Time step 1:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 323.72
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 304.63
# Time step 2:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 314.33
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 295.80
# Time step 3:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 324.34
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 305.22
# Time step 4:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 314.94
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 296.37
# Time step 5:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 324.97
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 305.81
# Time step 6:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 315.55
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 296.94
# Time step 7:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 325.59
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 306.40
# Time step 8:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 335.96
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 316.15
# Time step 9:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 326.22
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 306.99
# Time step 10:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 336.61
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 316.76
# Time step 11:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 326.85
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 307.58
# Time step 12:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 337.25
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 317.37
# Time step 13:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 327.48
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 308.17
# Time step 14:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 337.90
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 317.98
# Time step 15:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 328.11
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 308.76
# Time step 16:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 338.55
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 318.59
# Time step 17:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 328.74
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 309.36
# Time step 18:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 339.21
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 319.21
# Time step 19:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 329.37
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 309.95
# Time step 20:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 339.86
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 319.82
# Time step 21:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 330.00
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 310.55
# Time step 22:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 340.51
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 320.44
# Time step 23:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 330.64
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 311.15
# Time step 24:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 341.17
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 321.05
# Time step 25:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 331.28
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 311.75
# Time step 26:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 341.82
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 321.67
# Time step 27:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 331.91
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 312.35
# Time step 28:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 342.48
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 322.29
# Time step 29:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 332.55
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 312.95
# Time step 30:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 343.14
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 322.91
# Time step 31:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 333.19
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 313.55
# Time step 32:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 343.80
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 323.53
# Time step 33:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 333.83
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 314.15
# Time step 34:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 344.46
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 324.16
# Time step 35:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 334.48
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 314.76
# Time step 36:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 345.13
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 324.78
# Time step 37:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 335.12
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 315.36
# Time step 38:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 345.79
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 325.41
# Time step 39:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 335.77
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 315.97
# Time step 40:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 346.46
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 326.03
# Time step 41:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 336.41
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 316.58
# Time step 42:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 347.12
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 326.66
# Time step 43:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 337.06
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 317.19
# Time step 44:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 347.79
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 327.29
# Time step 45:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 337.71
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 317.80
# Time step 46:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 348.46
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 327.92
# Time step 47:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 338.36
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 318.41
# Time step 48:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 349.13
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 328.55
# Time step 49:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 339.01
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 319.02
# Time step 50:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 349.80
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 329.18
# Time step 51:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 339.66
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 319.64
# Time step 52:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 350.48
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 329.82
# Time step 53:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 340.32
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 320.25
# Time step 54:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 351.15
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 330.45
# Time step 55:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 340.97
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 320.87
# Time step 56:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 351.83
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 331.09
# Time step 57:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 341.63
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 321.49
# Time step 58:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 352.51
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 331.72
# Time step 59:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 363.73
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 342.29
# Time step 60:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 353.18
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 332.36
# Time step 61:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 364.43
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 342.94
# Time step 62:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 353.86
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 333.00
# Time step 63:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 365.13
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 343.60
# Time step 64:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 354.55
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 333.64
# Time step 65:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 365.83
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 344.27
# Time step 66:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 355.23
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 334.29
# Time step 67:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 366.54
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 344.93
# Time step 68:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 355.91
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 334.93
# Time step 69:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 367.24
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 345.59
# Time step 70:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 356.60
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 335.57
# Time step 71:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 367.95
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 346.26
# Time step 72:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 357.28
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 336.22
# Time step 73:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 368.66
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 346.92
# Time step 74:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 357.97
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 336.87
# Time step 75:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 369.37
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 347.59
# Time step 76:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 381.13
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 358.66
# Time step 77:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 370.08
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 348.26
# Time step 78:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 381.86
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 359.35
# Time step 79:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 370.79
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 348.93
# Time step 80:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 382.60
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 360.04
# Time step 81:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 371.51
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 349.60
# Time step 82:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 383.33
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 360.74
# Time step 83:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 372.22
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 350.28
# Time step 84:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 384.07
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 361.43
# Time step 85:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 372.94
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 350.95
# Time step 86:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 384.81
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 362.13
# Time step 87:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 397.06
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 373.66
# Time step 88:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 385.55
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 362.82
# Time step 89:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 397.83
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 374.37
# Time step 90:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 386.29
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 363.52
# Time step 91:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 398.59
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 375.10
# Time step 92:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 411.29
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 387.04
# Time step 93:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 399.36
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 375.82
# Time step 94:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 412.08
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 387.78
# Time step 95:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 400.13
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 376.54
# Time step 96:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 412.87
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 388.53
# Time step 97:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 426.02
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 400.90
# Time step 98:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 439.58
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 413.67
# Time step 99:
#   Stock price at i-th node where option_values > max(K - S_t^(i)): 453.58
#   Stock price at (i+1)-th node where option_values <= max(K - S_t^(i+1)): 426.84

# %% [markdown]
# # Plotting Free Boundary Path

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# Initialize lists to store the time steps and corresponding stock prices
time_steps = []
S_t_i_values = []
S_t_i_plus_1_values = []

# Assuming `results` contains the data from your previous analysis
# Iterate over the results and extract the time steps and stock prices
for j, i, stock_price_i, stock_price_next in results:
    time_steps.append(int(j))  # Ensure time steps are integers
    S_t_i_values.append(stock_price_i)
    S_t_i_plus_1_values.append(stock_price_next)

# Create the main figure
plt.figure(figsize=(10, 6))

# Plot the main graph with markers
plt.plot(time_steps, S_t_i_values, 'bD-', label="Hold Region", markersize=7)
plt.plot(time_steps, S_t_i_plus_1_values, 'rs-', label="Exercise Region", markersize=7)

# Labels and title
plt.xlabel('Time Step (t)')
plt.ylabel('Stock Price (S_t)')
plt.title('Free Boundary Path')

# Set x-ticks to intervals of 20
plt.xticks(range(min(time_steps), max(time_steps)+1, 20))  # Set x-ticks every 20 time steps

plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Create an inset plot (zoomed-in view for the last 30 time steps)
ax_inset = inset_axes(plt.gca(), width="35%", height="35%", loc='upper center')  # Change to bottom right

# Focus on the last 20 time steps (adjust this as needed)
num_steps = len(time_steps)
start_zoom = num_steps - 20

ax_inset.plot(time_steps[start_zoom:], S_t_i_values[start_zoom:], 'bD-', markersize=6)
ax_inset.plot(time_steps[start_zoom:], S_t_i_plus_1_values[start_zoom:], 'rs-', markersize=6)

# Set zoomed-in x and y limits based on the last 20 points
ax_inset.set_xlim(time_steps[start_zoom], time_steps[-1])
ax_inset.set_ylim(min(S_t_i_values[start_zoom:]), max(S_t_i_values[start_zoom:]) + 5)
ax_inset.grid(True, linestyle='--', alpha=0.7)

plt.savefig('Free_Boundary_Path_with_Inset.png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()
